# %%
import torch
import torch.nn as nn
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from torch import optim
from torch.autograd import Variable
from torch.utils.data.dataset import TensorDataset
from torch.utils.data.dataloader import DataLoader

# %%
i_set = 4

# %%
datasetname = 'detailed-1000pre'

# %%
readpath = './data/processed/cv1/{}/data_label_F_processed.csv'.format(datasetname)
df = pd.read_csv(readpath)
df = df.iloc[:,1:]

# %%
def data_sepration(in_data, val_id):
    """
    convert the df to dataset and seperate between
    train and validation set
    """
    trainset = torch.from_numpy(in_data[in_data.iloc[:,-1] != val_id].iloc[:,0:1000].values)
    traintarget = torch.from_numpy(in_data[in_data.iloc[:,-1] != val_id].iloc[:,[-5,-4]].values)
    valset = torch.from_numpy(in_data[in_data.iloc[:,-1] == val_id].iloc[:,0:1000].values)
    valtarget = torch.from_numpy(in_data[in_data.iloc[:,-1] == val_id].iloc[:,[-5,-4]].values)
    return trainset, valset, traintarget, valtarget

# %%
def accuarcy(pred, true):
    true = true.squeeze(1)
    pred = pred.reshape(-1)
    count = torch.sum((pred > true[:,0]) & (pred < true[:,1]))
#     print(pred)
#     print(true[:,0])
#     print(true[:,1])
#     print(100*count/pred.size(0))
    return 100.0*count/pred.size(0)

# %%
class SquareHingeLoss(nn.Module):
    def __init__(self):
        super(SquareHingeLoss,self).__init__()
    
    def ifelse(self, condition, a, b):
        crit = (condition >= 0).squeeze(1)
        copy_con = condition.clone()
        copy_con[crit] = condition[crit] ** 2
        copy_con[~crit] = b
        return copy_con

    def phi(self, in_phi):
        return self.ifelse(in_phi, in_phi**2, 0) 
       
    def forward(self, x, target_y):
#         print(torch.mean(self.phi(-x + target_y[:,:,0] + 1) + self.phi(x - target_y[:,:,1] + 1)))
        return torch.mean(self.phi(- x + target_y[:,:,0] + 1) + self.phi(x - target_y[:,:,1] + 1))

# %%
class convNet(nn.Module):
    def __init__(self):
        super(convNet, self).__init__()
        self.layer1 = nn.Sequential(
            nn.Conv1d(1, 8, 5, 3), # 8 x 332
            nn.ReLU(True),
            nn.Conv1d(8, 16, 3, 2, 1), # 16 x 166
            nn.ReLU(True),
            nn.Conv1d(16, 32, 3, 2, 1), # 32 x 83
            nn.ReLU(True),
            nn.Conv1d(32, 32, 3, 2, 1), # 32 x 42
            nn.ReLU(True)
        )
        self.layer2 = nn.Sequential(
            nn.Linear(32*42, 128),
            nn.ReLU(True),
            nn.Linear(128, 32),
            nn.ReLU(True),
            nn.Linear(32, 1)
        )
    
    def forward(self, x):
        x = x.float()
        x = self.layer1(x)
        x = x.reshape(x.size(0),-1)
        x = self.layer2(x)
        return x

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
model = convNet().to(device)
criterion = SquareHingeLoss()
optimier = optim.Adam(model.parameters(), lr=1e-4)

# %%
trainset, valset, traintarget, valtarget = data_sepration(df, i_set)
traindataset = TensorDataset(trainset.unsqueeze(1), traintarget.unsqueeze(1))
valdataset = TensorDataset(valset.unsqueeze(1), valtarget.unsqueeze(1))
trainLoader = DataLoader(traindataset, shuffle=True, batch_size=10000)
valLoader = DataLoader(valdataset, shuffle=True, batch_size=40)

# %%
e = 0
num_epoches = 3000
train_loss_record = np.zeros(num_epoches)
train_acc_record = np.zeros(num_epoches)
test_loss_record = np.zeros(num_epoches)
test_acc_record = np.zeros(num_epoches)
for epoch in range(num_epoches):
    loss_value, iter_num, print_loss = 0, 0, 0
    acc = 0
    for data in trainLoader:
        e += 1
        iter_num += 1
        inputs, targets = data
        inputs = Variable(inputs).to(device)
        targets = Variable(targets).to(device)
        inputs = inputs.type(torch.DoubleTensor).to(device)
        out = model(inputs)
        loss = criterion(out, targets.float())
        optimier.zero_grad()
        loss.backward()
        optimier.step()
        
        print_loss += loss.cpu().data.numpy()
        acc += accuarcy(out.cpu().data, targets.cpu().data.float()).data.numpy()
    
    test_in = Variable(valdataset.tensors[0]).to(device)
    test_in = test_in.type(torch.DoubleTensor).to(device)
    test_out = model(test_in)
    test_loss = criterion(test_out, Variable(valdataset.tensors[1].cuda()).float())
    test_loss = test_loss.cpu().data.numpy()
    test_acc = accuarcy(test_out.cpu().data, valdataset.tensors[1].float()).data.numpy()
        
    print('-'* 120)
    print('Epoch [{:-03d}/{}]  |  Train Loss:  {:.3f}  |  Test Loss:  {:.3f}  |  Test Accuarcy:  {:.3f}  |  Train Accuracy:  {:.3f}'
          .format(epoch+1, num_epoches, print_loss/iter_num, test_loss, test_acc, acc/iter_num))
    train_loss_record[epoch] = print_loss/iter_num
    test_loss_record[epoch] = test_loss
    train_acc_record[epoch] = acc/iter_num
    test_acc_record[epoch] = test_acc
# Out:
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [001/3000]  |  Train Loss:  0.491  |  Test Loss:  0.511  |  Test Accuarcy:  87.077  |  Train Accuracy:  89.481
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [002/3000]  |  Train Loss:  0.489  |  Test Loss:  0.509  |  Test Accuarcy:  87.077  |  Train Accuracy:  89.481
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [003/3000]  |  Train Loss:  0.487  |  Test Loss:  0.508  |  Test Accuarcy:  87.077  |  Train Accuracy:  89.448
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [004/3000]  |  Train Loss:  0.486  |  Test Loss:  0.507  |  Test Accuarcy:  87.077  |  Train Accuracy:  89.383
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [005/3000]  |  Train Loss:  0.484  |  Test Loss:  0.506  |  Test Accuarcy:  87.077  |  Train Accuracy:  89.383
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [006/3000]  |  Train Loss:  0.483  |  Test Loss:  0.505  |  Test Accuarcy:  87.077  |  Train Accuracy:  89.416
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [007/3000]  |  Train Loss:  0.481  |  Test Loss:  0.504  |  Test Accuarcy:  87.231  |  Train Accuracy:  89.416
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [008/3000]  |  Train Loss:  0.480  |  Test Loss:  0.504  |  Test Accuarcy:  87.385  |  Train Accuracy:  89.481
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [009/3000]  |  Train Loss:  0.478  |  Test Loss:  0.503  |  Test Accuarcy:  87.538  |  Train Accuracy:  89.545
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [010/3000]  |  Train Loss:  0.477  |  Test Loss:  0.502  |  Test Accuarcy:  87.385  |  Train Accuracy:  89.481
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [011/3000]  |  Train Loss:  0.476  |  Test Loss:  0.501  |  Test Accuarcy:  87.385  |  Train Accuracy:  89.545
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [012/3000]  |  Train Loss:  0.475  |  Test Loss:  0.501  |  Test Accuarcy:  87.385  |  Train Accuracy:  89.578
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [013/3000]  |  Train Loss:  0.474  |  Test Loss:  0.500  |  Test Accuarcy:  87.385  |  Train Accuracy:  89.545
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [014/3000]  |  Train Loss:  0.473  |  Test Loss:  0.500  |  Test Accuarcy:  87.385  |  Train Accuracy:  89.643
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [015/3000]  |  Train Loss:  0.472  |  Test Loss:  0.499  |  Test Accuarcy:  87.385  |  Train Accuracy:  89.675
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [016/3000]  |  Train Loss:  0.471  |  Test Loss:  0.498  |  Test Accuarcy:  87.385  |  Train Accuracy:  89.708
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [017/3000]  |  Train Loss:  0.470  |  Test Loss:  0.498  |  Test Accuarcy:  87.385  |  Train Accuracy:  89.740
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [018/3000]  |  Train Loss:  0.469  |  Test Loss:  0.497  |  Test Accuarcy:  87.538  |  Train Accuracy:  89.838
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [019/3000]  |  Train Loss:  0.468  |  Test Loss:  0.497  |  Test Accuarcy:  87.692  |  Train Accuracy:  89.805
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [020/3000]  |  Train Loss:  0.467  |  Test Loss:  0.496  |  Test Accuarcy:  87.692  |  Train Accuracy:  89.773
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [021/3000]  |  Train Loss:  0.466  |  Test Loss:  0.496  |  Test Accuarcy:  87.692  |  Train Accuracy:  89.740
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [022/3000]  |  Train Loss:  0.465  |  Test Loss:  0.495  |  Test Accuarcy:  87.538  |  Train Accuracy:  89.675
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [023/3000]  |  Train Loss:  0.464  |  Test Loss:  0.495  |  Test Accuarcy:  87.538  |  Train Accuracy:  89.643
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [024/3000]  |  Train Loss:  0.462  |  Test Loss:  0.495  |  Test Accuarcy:  87.385  |  Train Accuracy:  89.610
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [025/3000]  |  Train Loss:  0.462  |  Test Loss:  0.494  |  Test Accuarcy:  87.538  |  Train Accuracy:  89.773
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [026/3000]  |  Train Loss:  0.461  |  Test Loss:  0.494  |  Test Accuarcy:  87.538  |  Train Accuracy:  89.740
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [027/3000]  |  Train Loss:  0.460  |  Test Loss:  0.493  |  Test Accuarcy:  87.538  |  Train Accuracy:  89.805
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [028/3000]  |  Train Loss:  0.458  |  Test Loss:  0.493  |  Test Accuarcy:  87.538  |  Train Accuracy:  89.870
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [029/3000]  |  Train Loss:  0.457  |  Test Loss:  0.493  |  Test Accuarcy:  87.385  |  Train Accuracy:  89.838
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [030/3000]  |  Train Loss:  0.456  |  Test Loss:  0.492  |  Test Accuarcy:  87.231  |  Train Accuracy:  89.838
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [031/3000]  |  Train Loss:  0.455  |  Test Loss:  0.492  |  Test Accuarcy:  87.231  |  Train Accuracy:  89.773
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [032/3000]  |  Train Loss:  0.454  |  Test Loss:  0.492  |  Test Accuarcy:  87.231  |  Train Accuracy:  89.805
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [033/3000]  |  Train Loss:  0.453  |  Test Loss:  0.492  |  Test Accuarcy:  87.231  |  Train Accuracy:  89.838
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [034/3000]  |  Train Loss:  0.452  |  Test Loss:  0.492  |  Test Accuarcy:  87.231  |  Train Accuracy:  89.773
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [035/3000]  |  Train Loss:  0.451  |  Test Loss:  0.492  |  Test Accuarcy:  87.231  |  Train Accuracy:  89.773
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [036/3000]  |  Train Loss:  0.450  |  Test Loss:  0.492  |  Test Accuarcy:  87.385  |  Train Accuracy:  89.805
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [037/3000]  |  Train Loss:  0.449  |  Test Loss:  0.492  |  Test Accuarcy:  87.538  |  Train Accuracy:  89.805
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [038/3000]  |  Train Loss:  0.448  |  Test Loss:  0.492  |  Test Accuarcy:  87.385  |  Train Accuracy:  89.773
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [039/3000]  |  Train Loss:  0.447  |  Test Loss:  0.492  |  Test Accuarcy:  87.538  |  Train Accuracy:  89.805
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [040/3000]  |  Train Loss:  0.447  |  Test Loss:  0.492  |  Test Accuarcy:  87.692  |  Train Accuracy:  89.805
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [041/3000]  |  Train Loss:  0.446  |  Test Loss:  0.492  |  Test Accuarcy:  87.385  |  Train Accuracy:  89.838
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [042/3000]  |  Train Loss:  0.445  |  Test Loss:  0.493  |  Test Accuarcy:  87.538  |  Train Accuracy:  89.870
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [043/3000]  |  Train Loss:  0.444  |  Test Loss:  0.493  |  Test Accuarcy:  87.231  |  Train Accuracy:  89.968
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [044/3000]  |  Train Loss:  0.443  |  Test Loss:  0.494  |  Test Accuarcy:  86.923  |  Train Accuracy:  90.000
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [045/3000]  |  Train Loss:  0.443  |  Test Loss:  0.494  |  Test Accuarcy:  86.923  |  Train Accuracy:  90.065
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [046/3000]  |  Train Loss:  0.442  |  Test Loss:  0.495  |  Test Accuarcy:  87.077  |  Train Accuracy:  90.032
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [047/3000]  |  Train Loss:  0.442  |  Test Loss:  0.496  |  Test Accuarcy:  86.769  |  Train Accuracy:  90.065
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [048/3000]  |  Train Loss:  0.441  |  Test Loss:  0.497  |  Test Accuarcy:  86.769  |  Train Accuracy:  90.032
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [049/3000]  |  Train Loss:  0.441  |  Test Loss:  0.498  |  Test Accuarcy:  86.769  |  Train Accuracy:  89.968
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [050/3000]  |  Train Loss:  0.440  |  Test Loss:  0.499  |  Test Accuarcy:  86.769  |  Train Accuracy:  90.000
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [051/3000]  |  Train Loss:  0.440  |  Test Loss:  0.500  |  Test Accuarcy:  86.769  |  Train Accuracy:  89.870
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [052/3000]  |  Train Loss:  0.440  |  Test Loss:  0.501  |  Test Accuarcy:  86.615  |  Train Accuracy:  89.935
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [053/3000]  |  Train Loss:  0.440  |  Test Loss:  0.502  |  Test Accuarcy:  86.769  |  Train Accuracy:  89.903
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [054/3000]  |  Train Loss:  0.440  |  Test Loss:  0.503  |  Test Accuarcy:  86.615  |  Train Accuracy:  89.870
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [055/3000]  |  Train Loss:  0.440  |  Test Loss:  0.504  |  Test Accuarcy:  86.615  |  Train Accuracy:  89.838
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [056/3000]  |  Train Loss:  0.440  |  Test Loss:  0.505  |  Test Accuarcy:  86.615  |  Train Accuracy:  89.708
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [057/3000]  |  Train Loss:  0.440  |  Test Loss:  0.506  |  Test Accuarcy:  86.615  |  Train Accuracy:  89.675
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [058/3000]  |  Train Loss:  0.440  |  Test Loss:  0.507  |  Test Accuarcy:  86.615  |  Train Accuracy:  89.643
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [059/3000]  |  Train Loss:  0.440  |  Test Loss:  0.508  |  Test Accuarcy:  86.769  |  Train Accuracy:  89.545
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [060/3000]  |  Train Loss:  0.440  |  Test Loss:  0.508  |  Test Accuarcy:  86.769  |  Train Accuracy:  89.545
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [061/3000]  |  Train Loss:  0.440  |  Test Loss:  0.508  |  Test Accuarcy:  86.769  |  Train Accuracy:  89.545
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [062/3000]  |  Train Loss:  0.440  |  Test Loss:  0.508  |  Test Accuarcy:  86.769  |  Train Accuracy:  89.545
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [063/3000]  |  Train Loss:  0.440  |  Test Loss:  0.508  |  Test Accuarcy:  86.769  |  Train Accuracy:  89.545
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [064/3000]  |  Train Loss:  0.440  |  Test Loss:  0.508  |  Test Accuarcy:  86.769  |  Train Accuracy:  89.545
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [065/3000]  |  Train Loss:  0.440  |  Test Loss:  0.508  |  Test Accuarcy:  86.769  |  Train Accuracy:  89.545
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [066/3000]  |  Train Loss:  0.440  |  Test Loss:  0.508  |  Test Accuarcy:  86.769  |  Train Accuracy:  89.545
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [067/3000]  |  Train Loss:  0.440  |  Test Loss:  0.507  |  Test Accuarcy:  86.769  |  Train Accuracy:  89.545
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [068/3000]  |  Train Loss:  0.440  |  Test Loss:  0.507  |  Test Accuarcy:  86.769  |  Train Accuracy:  89.545
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [069/3000]  |  Train Loss:  0.440  |  Test Loss:  0.507  |  Test Accuarcy:  86.462  |  Train Accuracy:  89.545
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [070/3000]  |  Train Loss:  0.440  |  Test Loss:  0.506  |  Test Accuarcy:  86.615  |  Train Accuracy:  89.610
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [071/3000]  |  Train Loss:  0.440  |  Test Loss:  0.506  |  Test Accuarcy:  86.462  |  Train Accuracy:  89.643
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [072/3000]  |  Train Loss:  0.440  |  Test Loss:  0.505  |  Test Accuarcy:  86.615  |  Train Accuracy:  89.708
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [073/3000]  |  Train Loss:  0.440  |  Test Loss:  0.505  |  Test Accuarcy:  86.615  |  Train Accuracy:  89.643
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [074/3000]  |  Train Loss:  0.440  |  Test Loss:  0.504  |  Test Accuarcy:  86.615  |  Train Accuracy:  89.675
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [075/3000]  |  Train Loss:  0.440  |  Test Loss:  0.504  |  Test Accuarcy:  86.615  |  Train Accuracy:  89.740
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [076/3000]  |  Train Loss:  0.440  |  Test Loss:  0.503  |  Test Accuarcy:  86.615  |  Train Accuracy:  89.773
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [077/3000]  |  Train Loss:  0.440  |  Test Loss:  0.503  |  Test Accuarcy:  86.769  |  Train Accuracy:  89.838
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [078/3000]  |  Train Loss:  0.439  |  Test Loss:  0.503  |  Test Accuarcy:  86.769  |  Train Accuracy:  89.870
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [079/3000]  |  Train Loss:  0.439  |  Test Loss:  0.502  |  Test Accuarcy:  86.769  |  Train Accuracy:  89.870
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [080/3000]  |  Train Loss:  0.439  |  Test Loss:  0.502  |  Test Accuarcy:  86.769  |  Train Accuracy:  89.870
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [081/3000]  |  Train Loss:  0.439  |  Test Loss:  0.502  |  Test Accuarcy:  86.769  |  Train Accuracy:  89.870
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [082/3000]  |  Train Loss:  0.439  |  Test Loss:  0.502  |  Test Accuarcy:  86.769  |  Train Accuracy:  89.870
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [083/3000]  |  Train Loss:  0.439  |  Test Loss:  0.502  |  Test Accuarcy:  86.769  |  Train Accuracy:  89.870
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [084/3000]  |  Train Loss:  0.439  |  Test Loss:  0.502  |  Test Accuarcy:  86.615  |  Train Accuracy:  89.870
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [085/3000]  |  Train Loss:  0.439  |  Test Loss:  0.502  |  Test Accuarcy:  86.615  |  Train Accuracy:  89.838
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [086/3000]  |  Train Loss:  0.439  |  Test Loss:  0.502  |  Test Accuarcy:  86.615  |  Train Accuracy:  89.838
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [087/3000]  |  Train Loss:  0.439  |  Test Loss:  0.502  |  Test Accuarcy:  86.615  |  Train Accuracy:  89.838
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [088/3000]  |  Train Loss:  0.439  |  Test Loss:  0.502  |  Test Accuarcy:  86.615  |  Train Accuracy:  89.838
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [089/3000]  |  Train Loss:  0.439  |  Test Loss:  0.502  |  Test Accuarcy:  86.615  |  Train Accuracy:  89.838
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [090/3000]  |  Train Loss:  0.439  |  Test Loss:  0.502  |  Test Accuarcy:  86.769  |  Train Accuracy:  89.838
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [091/3000]  |  Train Loss:  0.439  |  Test Loss:  0.502  |  Test Accuarcy:  86.769  |  Train Accuracy:  89.838
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [092/3000]  |  Train Loss:  0.439  |  Test Loss:  0.502  |  Test Accuarcy:  86.769  |  Train Accuracy:  89.870
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [093/3000]  |  Train Loss:  0.439  |  Test Loss:  0.502  |  Test Accuarcy:  86.769  |  Train Accuracy:  89.870
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [094/3000]  |  Train Loss:  0.439  |  Test Loss:  0.502  |  Test Accuarcy:  86.769  |  Train Accuracy:  89.870
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [095/3000]  |  Train Loss:  0.439  |  Test Loss:  0.502  |  Test Accuarcy:  86.769  |  Train Accuracy:  89.870
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [096/3000]  |  Train Loss:  0.439  |  Test Loss:  0.502  |  Test Accuarcy:  86.769  |  Train Accuracy:  89.870
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [097/3000]  |  Train Loss:  0.439  |  Test Loss:  0.502  |  Test Accuarcy:  86.769  |  Train Accuracy:  89.870
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [098/3000]  |  Train Loss:  0.439  |  Test Loss:  0.502  |  Test Accuarcy:  86.769  |  Train Accuracy:  89.870
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [099/3000]  |  Train Loss:  0.439  |  Test Loss:  0.503  |  Test Accuarcy:  86.769  |  Train Accuracy:  89.870
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [100/3000]  |  Train Loss:  0.439  |  Test Loss:  0.503  |  Test Accuarcy:  86.769  |  Train Accuracy:  89.870
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [101/3000]  |  Train Loss:  0.439  |  Test Loss:  0.503  |  Test Accuarcy:  86.769  |  Train Accuracy:  89.870
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [102/3000]  |  Train Loss:  0.439  |  Test Loss:  0.503  |  Test Accuarcy:  86.769  |  Train Accuracy:  89.870
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [103/3000]  |  Train Loss:  0.439  |  Test Loss:  0.503  |  Test Accuarcy:  86.769  |  Train Accuracy:  89.870
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [104/3000]  |  Train Loss:  0.439  |  Test Loss:  0.503  |  Test Accuarcy:  86.769  |  Train Accuracy:  89.870
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [105/3000]  |  Train Loss:  0.439  |  Test Loss:  0.503  |  Test Accuarcy:  86.769  |  Train Accuracy:  89.870
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [106/3000]  |  Train Loss:  0.439  |  Test Loss:  0.503  |  Test Accuarcy:  86.769  |  Train Accuracy:  89.870
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [107/3000]  |  Train Loss:  0.439  |  Test Loss:  0.503  |  Test Accuarcy:  86.769  |  Train Accuracy:  89.870
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [108/3000]  |  Train Loss:  0.439  |  Test Loss:  0.503  |  Test Accuarcy:  86.769  |  Train Accuracy:  89.870
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [109/3000]  |  Train Loss:  0.439  |  Test Loss:  0.503  |  Test Accuarcy:  86.769  |  Train Accuracy:  89.870
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [110/3000]  |  Train Loss:  0.439  |  Test Loss:  0.503  |  Test Accuarcy:  86.769  |  Train Accuracy:  89.870
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [111/3000]  |  Train Loss:  0.439  |  Test Loss:  0.503  |  Test Accuarcy:  86.769  |  Train Accuracy:  89.870
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [112/3000]  |  Train Loss:  0.439  |  Test Loss:  0.503  |  Test Accuarcy:  86.769  |  Train Accuracy:  89.870
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [113/3000]  |  Train Loss:  0.439  |  Test Loss:  0.503  |  Test Accuarcy:  86.769  |  Train Accuracy:  89.870
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [114/3000]  |  Train Loss:  0.439  |  Test Loss:  0.503  |  Test Accuarcy:  86.769  |  Train Accuracy:  89.870
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [115/3000]  |  Train Loss:  0.439  |  Test Loss:  0.503  |  Test Accuarcy:  86.769  |  Train Accuracy:  89.870
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [116/3000]  |  Train Loss:  0.439  |  Test Loss:  0.503  |  Test Accuarcy:  86.769  |  Train Accuracy:  89.870
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [117/3000]  |  Train Loss:  0.439  |  Test Loss:  0.503  |  Test Accuarcy:  86.769  |  Train Accuracy:  89.870
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [118/3000]  |  Train Loss:  0.439  |  Test Loss:  0.503  |  Test Accuarcy:  86.769  |  Train Accuracy:  89.870
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [119/3000]  |  Train Loss:  0.439  |  Test Loss:  0.503  |  Test Accuarcy:  86.769  |  Train Accuracy:  89.870
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [120/3000]  |  Train Loss:  0.439  |  Test Loss:  0.503  |  Test Accuarcy:  86.769  |  Train Accuracy:  89.870
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [121/3000]  |  Train Loss:  0.439  |  Test Loss:  0.503  |  Test Accuarcy:  86.769  |  Train Accuracy:  89.870
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [122/3000]  |  Train Loss:  0.439  |  Test Loss:  0.503  |  Test Accuarcy:  86.769  |  Train Accuracy:  89.870
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [123/3000]  |  Train Loss:  0.439  |  Test Loss:  0.503  |  Test Accuarcy:  86.769  |  Train Accuracy:  89.870
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [124/3000]  |  Train Loss:  0.439  |  Test Loss:  0.502  |  Test Accuarcy:  86.769  |  Train Accuracy:  89.870
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [125/3000]  |  Train Loss:  0.439  |  Test Loss:  0.502  |  Test Accuarcy:  86.769  |  Train Accuracy:  89.870
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [126/3000]  |  Train Loss:  0.439  |  Test Loss:  0.502  |  Test Accuarcy:  86.769  |  Train Accuracy:  89.870
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [127/3000]  |  Train Loss:  0.439  |  Test Loss:  0.502  |  Test Accuarcy:  86.769  |  Train Accuracy:  89.870
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [128/3000]  |  Train Loss:  0.439  |  Test Loss:  0.502  |  Test Accuarcy:  86.769  |  Train Accuracy:  89.870
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [129/3000]  |  Train Loss:  0.439  |  Test Loss:  0.502  |  Test Accuarcy:  86.769  |  Train Accuracy:  89.870
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [130/3000]  |  Train Loss:  0.439  |  Test Loss:  0.502  |  Test Accuarcy:  86.769  |  Train Accuracy:  89.870
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [131/3000]  |  Train Loss:  0.439  |  Test Loss:  0.502  |  Test Accuarcy:  86.769  |  Train Accuracy:  89.870
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [132/3000]  |  Train Loss:  0.439  |  Test Loss:  0.502  |  Test Accuarcy:  86.769  |  Train Accuracy:  89.870
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [133/3000]  |  Train Loss:  0.439  |  Test Loss:  0.502  |  Test Accuarcy:  86.769  |  Train Accuracy:  89.838
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [134/3000]  |  Train Loss:  0.439  |  Test Loss:  0.502  |  Test Accuarcy:  86.769  |  Train Accuracy:  89.838
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [135/3000]  |  Train Loss:  0.439  |  Test Loss:  0.502  |  Test Accuarcy:  86.769  |  Train Accuracy:  89.838
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [136/3000]  |  Train Loss:  0.438  |  Test Loss:  0.502  |  Test Accuarcy:  86.769  |  Train Accuracy:  89.838
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [137/3000]  |  Train Loss:  0.438  |  Test Loss:  0.502  |  Test Accuarcy:  86.769  |  Train Accuracy:  89.838
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [138/3000]  |  Train Loss:  0.438  |  Test Loss:  0.502  |  Test Accuarcy:  86.769  |  Train Accuracy:  89.838
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [139/3000]  |  Train Loss:  0.438  |  Test Loss:  0.502  |  Test Accuarcy:  86.769  |  Train Accuracy:  89.838
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [140/3000]  |  Train Loss:  0.438  |  Test Loss:  0.502  |  Test Accuarcy:  86.769  |  Train Accuracy:  89.838
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [141/3000]  |  Train Loss:  0.438  |  Test Loss:  0.502  |  Test Accuarcy:  86.769  |  Train Accuracy:  89.838
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [142/3000]  |  Train Loss:  0.438  |  Test Loss:  0.502  |  Test Accuarcy:  86.769  |  Train Accuracy:  89.838
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [143/3000]  |  Train Loss:  0.438  |  Test Loss:  0.502  |  Test Accuarcy:  86.615  |  Train Accuracy:  89.838
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [144/3000]  |  Train Loss:  0.438  |  Test Loss:  0.502  |  Test Accuarcy:  86.615  |  Train Accuracy:  89.838
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [145/3000]  |  Train Loss:  0.438  |  Test Loss:  0.502  |  Test Accuarcy:  86.615  |  Train Accuracy:  89.838
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [146/3000]  |  Train Loss:  0.438  |  Test Loss:  0.502  |  Test Accuarcy:  86.615  |  Train Accuracy:  89.838
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [147/3000]  |  Train Loss:  0.438  |  Test Loss:  0.502  |  Test Accuarcy:  86.615  |  Train Accuracy:  89.838
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [148/3000]  |  Train Loss:  0.438  |  Test Loss:  0.502  |  Test Accuarcy:  86.615  |  Train Accuracy:  89.838
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [149/3000]  |  Train Loss:  0.438  |  Test Loss:  0.502  |  Test Accuarcy:  86.615  |  Train Accuracy:  89.838
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [150/3000]  |  Train Loss:  0.438  |  Test Loss:  0.502  |  Test Accuarcy:  86.615  |  Train Accuracy:  89.838
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [151/3000]  |  Train Loss:  0.438  |  Test Loss:  0.502  |  Test Accuarcy:  86.615  |  Train Accuracy:  89.838
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [152/3000]  |  Train Loss:  0.438  |  Test Loss:  0.502  |  Test Accuarcy:  86.615  |  Train Accuracy:  89.838
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [153/3000]  |  Train Loss:  0.438  |  Test Loss:  0.502  |  Test Accuarcy:  86.615  |  Train Accuracy:  89.838
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [154/3000]  |  Train Loss:  0.438  |  Test Loss:  0.502  |  Test Accuarcy:  86.615  |  Train Accuracy:  89.838
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [155/3000]  |  Train Loss:  0.438  |  Test Loss:  0.502  |  Test Accuarcy:  86.615  |  Train Accuracy:  89.838
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [156/3000]  |  Train Loss:  0.438  |  Test Loss:  0.502  |  Test Accuarcy:  86.615  |  Train Accuracy:  89.838
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [157/3000]  |  Train Loss:  0.438  |  Test Loss:  0.502  |  Test Accuarcy:  86.615  |  Train Accuracy:  89.838
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [158/3000]  |  Train Loss:  0.438  |  Test Loss:  0.502  |  Test Accuarcy:  86.615  |  Train Accuracy:  89.838
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [159/3000]  |  Train Loss:  0.438  |  Test Loss:  0.502  |  Test Accuarcy:  86.615  |  Train Accuracy:  89.838
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [160/3000]  |  Train Loss:  0.438  |  Test Loss:  0.502  |  Test Accuarcy:  86.615  |  Train Accuracy:  89.838
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [161/3000]  |  Train Loss:  0.438  |  Test Loss:  0.502  |  Test Accuarcy:  86.615  |  Train Accuracy:  89.838
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [162/3000]  |  Train Loss:  0.438  |  Test Loss:  0.502  |  Test Accuarcy:  86.615  |  Train Accuracy:  89.838
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [163/3000]  |  Train Loss:  0.438  |  Test Loss:  0.501  |  Test Accuarcy:  86.615  |  Train Accuracy:  89.838
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [164/3000]  |  Train Loss:  0.437  |  Test Loss:  0.501  |  Test Accuarcy:  86.615  |  Train Accuracy:  89.838
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [165/3000]  |  Train Loss:  0.437  |  Test Loss:  0.501  |  Test Accuarcy:  86.615  |  Train Accuracy:  89.838
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [166/3000]  |  Train Loss:  0.437  |  Test Loss:  0.501  |  Test Accuarcy:  86.615  |  Train Accuracy:  89.838
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [167/3000]  |  Train Loss:  0.437  |  Test Loss:  0.501  |  Test Accuarcy:  86.615  |  Train Accuracy:  89.838
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [168/3000]  |  Train Loss:  0.437  |  Test Loss:  0.501  |  Test Accuarcy:  86.615  |  Train Accuracy:  89.838
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [169/3000]  |  Train Loss:  0.437  |  Test Loss:  0.502  |  Test Accuarcy:  86.615  |  Train Accuracy:  89.838
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [170/3000]  |  Train Loss:  0.437  |  Test Loss:  0.502  |  Test Accuarcy:  86.615  |  Train Accuracy:  89.805
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [171/3000]  |  Train Loss:  0.437  |  Test Loss:  0.502  |  Test Accuarcy:  86.615  |  Train Accuracy:  89.773
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [172/3000]  |  Train Loss:  0.437  |  Test Loss:  0.502  |  Test Accuarcy:  86.615  |  Train Accuracy:  89.870
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [173/3000]  |  Train Loss:  0.437  |  Test Loss:  0.502  |  Test Accuarcy:  86.615  |  Train Accuracy:  89.870
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [174/3000]  |  Train Loss:  0.437  |  Test Loss:  0.502  |  Test Accuarcy:  86.615  |  Train Accuracy:  89.870
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [175/3000]  |  Train Loss:  0.437  |  Test Loss:  0.502  |  Test Accuarcy:  86.615  |  Train Accuracy:  89.870
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [176/3000]  |  Train Loss:  0.437  |  Test Loss:  0.502  |  Test Accuarcy:  86.615  |  Train Accuracy:  89.870
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [177/3000]  |  Train Loss:  0.437  |  Test Loss:  0.501  |  Test Accuarcy:  86.615  |  Train Accuracy:  89.870
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [178/3000]  |  Train Loss:  0.437  |  Test Loss:  0.501  |  Test Accuarcy:  86.615  |  Train Accuracy:  89.870
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [179/3000]  |  Train Loss:  0.437  |  Test Loss:  0.501  |  Test Accuarcy:  86.615  |  Train Accuracy:  89.870
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [180/3000]  |  Train Loss:  0.437  |  Test Loss:  0.501  |  Test Accuarcy:  86.615  |  Train Accuracy:  89.870
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [181/3000]  |  Train Loss:  0.437  |  Test Loss:  0.501  |  Test Accuarcy:  86.615  |  Train Accuracy:  89.870
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [182/3000]  |  Train Loss:  0.437  |  Test Loss:  0.501  |  Test Accuarcy:  86.615  |  Train Accuracy:  89.870
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [183/3000]  |  Train Loss:  0.437  |  Test Loss:  0.501  |  Test Accuarcy:  86.615  |  Train Accuracy:  89.870
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [184/3000]  |  Train Loss:  0.436  |  Test Loss:  0.501  |  Test Accuarcy:  86.615  |  Train Accuracy:  89.870
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [185/3000]  |  Train Loss:  0.436  |  Test Loss:  0.501  |  Test Accuarcy:  86.615  |  Train Accuracy:  89.870
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [186/3000]  |  Train Loss:  0.436  |  Test Loss:  0.501  |  Test Accuarcy:  86.615  |  Train Accuracy:  89.870
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [187/3000]  |  Train Loss:  0.436  |  Test Loss:  0.501  |  Test Accuarcy:  86.615  |  Train Accuracy:  89.870
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [188/3000]  |  Train Loss:  0.436  |  Test Loss:  0.501  |  Test Accuarcy:  86.615  |  Train Accuracy:  89.870
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [189/3000]  |  Train Loss:  0.436  |  Test Loss:  0.501  |  Test Accuarcy:  86.615  |  Train Accuracy:  89.870
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [190/3000]  |  Train Loss:  0.436  |  Test Loss:  0.501  |  Test Accuarcy:  86.615  |  Train Accuracy:  89.870
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [191/3000]  |  Train Loss:  0.436  |  Test Loss:  0.501  |  Test Accuarcy:  86.615  |  Train Accuracy:  89.870
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [192/3000]  |  Train Loss:  0.436  |  Test Loss:  0.501  |  Test Accuarcy:  86.615  |  Train Accuracy:  89.903
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [193/3000]  |  Train Loss:  0.436  |  Test Loss:  0.501  |  Test Accuarcy:  86.615  |  Train Accuracy:  89.903
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [194/3000]  |  Train Loss:  0.436  |  Test Loss:  0.501  |  Test Accuarcy:  86.615  |  Train Accuracy:  89.903
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [195/3000]  |  Train Loss:  0.436  |  Test Loss:  0.501  |  Test Accuarcy:  86.615  |  Train Accuracy:  89.903
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [196/3000]  |  Train Loss:  0.436  |  Test Loss:  0.501  |  Test Accuarcy:  86.615  |  Train Accuracy:  89.903
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [197/3000]  |  Train Loss:  0.436  |  Test Loss:  0.500  |  Test Accuarcy:  86.615  |  Train Accuracy:  89.903
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [198/3000]  |  Train Loss:  0.435  |  Test Loss:  0.500  |  Test Accuarcy:  86.615  |  Train Accuracy:  89.903
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [199/3000]  |  Train Loss:  0.435  |  Test Loss:  0.500  |  Test Accuarcy:  86.615  |  Train Accuracy:  89.903
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [200/3000]  |  Train Loss:  0.435  |  Test Loss:  0.500  |  Test Accuarcy:  86.615  |  Train Accuracy:  89.903
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [201/3000]  |  Train Loss:  0.435  |  Test Loss:  0.500  |  Test Accuarcy:  86.615  |  Train Accuracy:  89.903
# ------------------------------------------------------------------------------------------------------------------------
# ...
# Epoch [2934/3000]  |  Train Loss:  0.024  |  Test Loss:  0.613  |  Test Accuarcy:  90.154  |  Train Accuracy:  99.740
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [2935/3000]  |  Train Loss:  0.024  |  Test Loss:  0.609  |  Test Accuarcy:  90.154  |  Train Accuracy:  99.740
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [2936/3000]  |  Train Loss:  0.024  |  Test Loss:  0.615  |  Test Accuarcy:  90.308  |  Train Accuracy:  99.740
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [2937/3000]  |  Train Loss:  0.024  |  Test Loss:  0.609  |  Test Accuarcy:  90.308  |  Train Accuracy:  99.740
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [2938/3000]  |  Train Loss:  0.024  |  Test Loss:  0.616  |  Test Accuarcy:  90.308  |  Train Accuracy:  99.708
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [2939/3000]  |  Train Loss:  0.024  |  Test Loss:  0.608  |  Test Accuarcy:  90.308  |  Train Accuracy:  99.740
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [2940/3000]  |  Train Loss:  0.024  |  Test Loss:  0.617  |  Test Accuarcy:  90.154  |  Train Accuracy:  99.708
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [2941/3000]  |  Train Loss:  0.024  |  Test Loss:  0.608  |  Test Accuarcy:  90.308  |  Train Accuracy:  99.740
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [2942/3000]  |  Train Loss:  0.024  |  Test Loss:  0.617  |  Test Accuarcy:  90.154  |  Train Accuracy:  99.708
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [2943/3000]  |  Train Loss:  0.024  |  Test Loss:  0.608  |  Test Accuarcy:  90.308  |  Train Accuracy:  99.740
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [2944/3000]  |  Train Loss:  0.024  |  Test Loss:  0.617  |  Test Accuarcy:  90.308  |  Train Accuracy:  99.708
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [2945/3000]  |  Train Loss:  0.024  |  Test Loss:  0.609  |  Test Accuarcy:  90.308  |  Train Accuracy:  99.740
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [2946/3000]  |  Train Loss:  0.024  |  Test Loss:  0.615  |  Test Accuarcy:  90.308  |  Train Accuracy:  99.708
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [2947/3000]  |  Train Loss:  0.024  |  Test Loss:  0.610  |  Test Accuarcy:  90.154  |  Train Accuracy:  99.740
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [2948/3000]  |  Train Loss:  0.024  |  Test Loss:  0.614  |  Test Accuarcy:  90.154  |  Train Accuracy:  99.740
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [2949/3000]  |  Train Loss:  0.024  |  Test Loss:  0.612  |  Test Accuarcy:  90.462  |  Train Accuracy:  99.740
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [2950/3000]  |  Train Loss:  0.024  |  Test Loss:  0.612  |  Test Accuarcy:  90.615  |  Train Accuracy:  99.740
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [2951/3000]  |  Train Loss:  0.024  |  Test Loss:  0.613  |  Test Accuarcy:  90.154  |  Train Accuracy:  99.740
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [2952/3000]  |  Train Loss:  0.024  |  Test Loss:  0.611  |  Test Accuarcy:  90.308  |  Train Accuracy:  99.740
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [2953/3000]  |  Train Loss:  0.024  |  Test Loss:  0.615  |  Test Accuarcy:  90.308  |  Train Accuracy:  99.740
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [2954/3000]  |  Train Loss:  0.024  |  Test Loss:  0.610  |  Test Accuarcy:  90.154  |  Train Accuracy:  99.740
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [2955/3000]  |  Train Loss:  0.024  |  Test Loss:  0.616  |  Test Accuarcy:  90.308  |  Train Accuracy:  99.740
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [2956/3000]  |  Train Loss:  0.024  |  Test Loss:  0.609  |  Test Accuarcy:  90.154  |  Train Accuracy:  99.740
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [2957/3000]  |  Train Loss:  0.024  |  Test Loss:  0.617  |  Test Accuarcy:  90.308  |  Train Accuracy:  99.708
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [2958/3000]  |  Train Loss:  0.024  |  Test Loss:  0.609  |  Test Accuarcy:  90.308  |  Train Accuracy:  99.740
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [2959/3000]  |  Train Loss:  0.024  |  Test Loss:  0.618  |  Test Accuarcy:  90.154  |  Train Accuracy:  99.708
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [2960/3000]  |  Train Loss:  0.024  |  Test Loss:  0.608  |  Test Accuarcy:  90.308  |  Train Accuracy:  99.740
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [2961/3000]  |  Train Loss:  0.024  |  Test Loss:  0.619  |  Test Accuarcy:  90.154  |  Train Accuracy:  99.708
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [2962/3000]  |  Train Loss:  0.024  |  Test Loss:  0.608  |  Test Accuarcy:  90.308  |  Train Accuracy:  99.740
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [2963/3000]  |  Train Loss:  0.024  |  Test Loss:  0.618  |  Test Accuarcy:  90.308  |  Train Accuracy:  99.708
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [2964/3000]  |  Train Loss:  0.024  |  Test Loss:  0.609  |  Test Accuarcy:  90.154  |  Train Accuracy:  99.740
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [2965/3000]  |  Train Loss:  0.024  |  Test Loss:  0.616  |  Test Accuarcy:  90.308  |  Train Accuracy:  99.708
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [2966/3000]  |  Train Loss:  0.024  |  Test Loss:  0.611  |  Test Accuarcy:  90.154  |  Train Accuracy:  99.740
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [2967/3000]  |  Train Loss:  0.024  |  Test Loss:  0.614  |  Test Accuarcy:  90.308  |  Train Accuracy:  99.740
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [2968/3000]  |  Train Loss:  0.024  |  Test Loss:  0.613  |  Test Accuarcy:  90.615  |  Train Accuracy:  99.740
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [2969/3000]  |  Train Loss:  0.024  |  Test Loss:  0.613  |  Test Accuarcy:  90.615  |  Train Accuracy:  99.740
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [2970/3000]  |  Train Loss:  0.024  |  Test Loss:  0.615  |  Test Accuarcy:  90.308  |  Train Accuracy:  99.740
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [2971/3000]  |  Train Loss:  0.024  |  Test Loss:  0.612  |  Test Accuarcy:  90.308  |  Train Accuracy:  99.740
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [2972/3000]  |  Train Loss:  0.024  |  Test Loss:  0.617  |  Test Accuarcy:  90.308  |  Train Accuracy:  99.740
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [2973/3000]  |  Train Loss:  0.024  |  Test Loss:  0.611  |  Test Accuarcy:  90.154  |  Train Accuracy:  99.740
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [2974/3000]  |  Train Loss:  0.024  |  Test Loss:  0.618  |  Test Accuarcy:  90.308  |  Train Accuracy:  99.740
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [2975/3000]  |  Train Loss:  0.024  |  Test Loss:  0.610  |  Test Accuarcy:  90.308  |  Train Accuracy:  99.740
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [2976/3000]  |  Train Loss:  0.024  |  Test Loss:  0.619  |  Test Accuarcy:  90.154  |  Train Accuracy:  99.708
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [2977/3000]  |  Train Loss:  0.024  |  Test Loss:  0.610  |  Test Accuarcy:  90.308  |  Train Accuracy:  99.740
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [2978/3000]  |  Train Loss:  0.024  |  Test Loss:  0.620  |  Test Accuarcy:  90.154  |  Train Accuracy:  99.708
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [2979/3000]  |  Train Loss:  0.024  |  Test Loss:  0.610  |  Test Accuarcy:  90.308  |  Train Accuracy:  99.740
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [2980/3000]  |  Train Loss:  0.024  |  Test Loss:  0.619  |  Test Accuarcy:  90.154  |  Train Accuracy:  99.708
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [2981/3000]  |  Train Loss:  0.024  |  Test Loss:  0.611  |  Test Accuarcy:  90.308  |  Train Accuracy:  99.740
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [2982/3000]  |  Train Loss:  0.024  |  Test Loss:  0.617  |  Test Accuarcy:  90.308  |  Train Accuracy:  99.708
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [2983/3000]  |  Train Loss:  0.024  |  Test Loss:  0.612  |  Test Accuarcy:  90.615  |  Train Accuracy:  99.740
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [2984/3000]  |  Train Loss:  0.023  |  Test Loss:  0.615  |  Test Accuarcy:  90.462  |  Train Accuracy:  99.740
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [2985/3000]  |  Train Loss:  0.023  |  Test Loss:  0.615  |  Test Accuarcy:  90.615  |  Train Accuracy:  99.740
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [2986/3000]  |  Train Loss:  0.023  |  Test Loss:  0.614  |  Test Accuarcy:  90.615  |  Train Accuracy:  99.740
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [2987/3000]  |  Train Loss:  0.023  |  Test Loss:  0.616  |  Test Accuarcy:  90.308  |  Train Accuracy:  99.740
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [2988/3000]  |  Train Loss:  0.023  |  Test Loss:  0.612  |  Test Accuarcy:  90.154  |  Train Accuracy:  99.740
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [2989/3000]  |  Train Loss:  0.023  |  Test Loss:  0.618  |  Test Accuarcy:  90.308  |  Train Accuracy:  99.740
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [2990/3000]  |  Train Loss:  0.023  |  Test Loss:  0.611  |  Test Accuarcy:  90.308  |  Train Accuracy:  99.740
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [2991/3000]  |  Train Loss:  0.023  |  Test Loss:  0.619  |  Test Accuarcy:  90.154  |  Train Accuracy:  99.708
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [2992/3000]  |  Train Loss:  0.024  |  Test Loss:  0.611  |  Test Accuarcy:  90.308  |  Train Accuracy:  99.740
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [2993/3000]  |  Train Loss:  0.024  |  Test Loss:  0.620  |  Test Accuarcy:  90.154  |  Train Accuracy:  99.708
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [2994/3000]  |  Train Loss:  0.024  |  Test Loss:  0.611  |  Test Accuarcy:  90.308  |  Train Accuracy:  99.740
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [2995/3000]  |  Train Loss:  0.024  |  Test Loss:  0.619  |  Test Accuarcy:  90.154  |  Train Accuracy:  99.708
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [2996/3000]  |  Train Loss:  0.024  |  Test Loss:  0.611  |  Test Accuarcy:  90.308  |  Train Accuracy:  99.740
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [2997/3000]  |  Train Loss:  0.023  |  Test Loss:  0.618  |  Test Accuarcy:  90.308  |  Train Accuracy:  99.708
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [2998/3000]  |  Train Loss:  0.023  |  Test Loss:  0.612  |  Test Accuarcy:  90.154  |  Train Accuracy:  99.740
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [2999/3000]  |  Train Loss:  0.023  |  Test Loss:  0.617  |  Test Accuarcy:  90.308  |  Train Accuracy:  99.740
# ------------------------------------------------------------------------------------------------------------------------
# Epoch [3000/3000]  |  Train Loss:  0.023  |  Test Loss:  0.613  |  Test Accuarcy:  90.769  |  Train Accuracy:  99.740

# %%
plt.plot(test_loss_record)
plt.plot(train_loss_record)
plt.show()

# %%
plt.plot(test_acc_record)
plt.plot(train_acc_record)
plt.plot(train_acc_record)
plt.show()

# %%
model.eval()
# Out:
# convNet(
#   (layer1): Sequential(
#     (0): Conv1d(1, 8, kernel_size=(5,), stride=(3,))
#     (1): ReLU(inplace=True)
#     (2): Conv1d(8, 16, kernel_size=(3,), stride=(2,), padding=(1,))
#     (3): ReLU(inplace=True)
#     (4): Conv1d(16, 32, kernel_size=(3,), stride=(2,), padding=(1,))
#     (5): ReLU(inplace=True)
#     (6): Conv1d(32, 32, kernel_size=(3,), stride=(2,), padding=(1,))
#     (7): ReLU(inplace=True)
#   )
#   (layer2): Sequential(
#     (0): Linear(in_features=1344, out_features=128, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Linear(in_features=128, out_features=32, bias=True)
#     (3): ReLU(inplace=True)
#     (4): Linear(in_features=32, out_features=1, bias=True)
#   )
# )

# %%
store_target = pd.DataFrame(columns={'i_set','dataset','train_acc','test_acc','train_loss','test_loss'})

# %%
store_target['train_loss'] = train_loss_record
store_target['test_loss'] = test_loss_record
store_target['train_acc'] = train_acc_record
store_target['test_acc'] = test_acc_record
store_target['i_set'] = i_set
store_target['dataset'] = datasetname

# %%
test_acc_record.max()
# Out:
# 92.30769348144531

# %%
path = './mem-1000pre/' + datasetname +'/' + str(i_set) + '_record.csv'
store_target.to_csv(path, index=False)

# %%
store_target
# Out:
#       i_set   test_acc           dataset  train_acc  test_loss  train_loss
# 0         4  87.076920  detailed-1000pre  89.480522   0.510563    0.490969
# 1         4  87.076920  detailed-1000pre  89.480522   0.509353    0.489071
# 2         4  87.076920  detailed-1000pre  89.448051   0.508246    0.487284
# 3         4  87.076920  detailed-1000pre  89.383118   0.507224    0.485630
# 4         4  87.076920  detailed-1000pre  89.383118   0.506250    0.484093
# ...     ...        ...               ...        ...        ...         ...
# 2995      4  90.307693  detailed-1000pre  99.740257   0.611047    0.023508
# 2996      4  90.307693  detailed-1000pre  99.707794   0.618448    0.023438
# 2997      4  90.153847  detailed-1000pre  99.740257   0.612156    0.023377
# 2998      4  90.307693  detailed-1000pre  99.740257   0.617251    0.023314
# 2999      4  90.769234  detailed-1000pre  99.740257   0.613210    0.023259
#
# [3000 rows x 6 columns]
